# %%
import requests
import re
from bs4 import BeautifulSoup

# %%
# 获取JJ的所有专辑
album_ids = []
album_names = []
# 不超过100个专辑，直接在一个页面显示
url_albums = "https://music.163.com/artist/album?id=3684&limit=100&offset=0"
headers = {
    'User-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

res = requests.get(url=url_albums, headers=headers)
soup = BeautifulSoup(res.text, "lxml")

# 专辑id的特征为保存在a标签的href中
pattern = r'^/album\?id=\d+'
def is_album_a(tag):
    return tag.has_attr('href') and re.search(pattern=pattern, string=tag['href']) and len(tag['class']) != 1
for d in soup.find_all(is_album_a):
    album_ids.append(d['href'][10:])
    album_names.append(d.get_text())

# %%
len(album_ids)
# Out:
# 75

# %%
# 获取各张专辑中的歌曲
all_songs = []
# 专辑页面
url_songs = "https://music.163.com/album?id="

def get_songs(album_id):
    res = requests.get(url=url_songs + album_id, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")

    pattern = r'^/song\?id=\d+'
    def is_song_a(tag):
        return tag.has_attr('href') and re.search(pattern=pattern, string=tag['href'])
    for d in soup.find_all(is_song_a):
        all_songs.append(d.get_text())
    
for album_id in album_ids:
    get_songs(album_id=album_id)

# %%
all_songs
# Out:
# ['The Show',
#  '愿与愁',
#  '逆光白',
#  '孤独娱乐',
#  '梦不凌乱',
#  '自画像',
#  '谢幕',
#  '如果我还剩一件事情可以做',
#  '黑色泡沫',
#  '你都在',
#  '一时的选择',
#  'Castle in the air',
#  '7千3百多天',
#  '愿与愁',
#  'In The Joy',
#  '谢幕',
#  'Intro',
#  'Too Bad',
#  '身后',
#  '想见你想见你想见你',
#  '恨幸福来过',
#  '慢慢喜欢你',
#  'You Are The Reason',
#  '咖啡+交换余生',
#  '圣所',
#  '生生',
#  '我还年轻 我还年轻',
#  '你啊你啊',
#  '那女孩对我说',
#  '落在生命里的光',
#  '是你',
#  '达尔文',
#  '7千3百多天',
#  '那些你很冒险的梦 (JJ20版)',
#  '无拘',
#  'From The Ashes',
#  'At Least I Had You',
#  "You're My Superhero",
#  'Positive Procrastination',
#  '一天加點愛 (feat. Karencici)',
#  'Help!',
#  'What Are We Doing? (with lewloh)',
#  'Better With You',
#  '你還不知道?',
#  'A Day At A Time',
#  '一定会',
#  'After The Rain',
#  'At Least I Had You',
#  '裹着心的光',
#  'While I Can',
#  'Like You Do',
#  'Not Tonight',
#  'All In Your Mind',
#  'Head On',
#  'Steady My Love',
#  'Bedroom (feat. Anne-Marie)',
#  'Not Tonight (Tomorrow Sounds Good Steve Aoki Remix)',
#  '修炼爱情 (Jazz Version)',
#  '伟大的渺小 (Jazz Version)',
#  '过',
#  '过 (伴奏)',
#  '最向往的地方',
#  '交换余生',
#  '幸存者',
#  '离开的那一些',
#  '最好是',
#  '暂时的记号',
#  '交换余生',
#  'Stay With You (英文版)',
#  '无滤镜 (feat. 藤原浩)',
#  'Hello (录音室版)',
#  '背对背拥抱',
#  'As I Believe',
#  'Wonderland',
#  '将故事写成我们',
#  '对的时间点',
#  'As I Believe',
#  '我们很好',
#  '进阶',
#  '飞云之下',
#  'Despacito 缓缓',
#  '圣所',
#  '伟大的渺小',
#  '穿越',
#  '四点四十四',
#  '我继续',
#  '剪云者',
#  '黑夜问白天',
#  '丹宁执着',
#  '身为风帆',
#  '小瓶子',
#  'Until the Day',
#  '黑夜问白天',
#  '小瓶子',
#  '伟大的渺小',
#  'Until The Day',
#  '丹宁执着',
#  '2infinity And Beyond',
#  '超越无限',
#  '序曲：调音',
#  '不为谁而作的歌',
#  '序曲：中场休息',
#  '关键词',
#  '只要有你的地方 (晚安版)',
#  '弹唱',
#  '有梦不难',
#  '序曲：Welcome to the Livehouse',
#  'Too Bad',
#  '你，有没有过 (Livehouse版)',
#  '序曲：12年前',
#  '现在的我和她',
#  '序曲：海边 初',
#  'Lier and Accuser',
#  '独舞',
#  '序曲：海边 终',
#  '你，有没有过',
#  '只要有你的地方',
#  '只要有你的地方(晚安版)',
#  '有梦不难',
#  '不为谁而作的歌',
#  'Dreams',
#  '只要有你的地方',
#  '全面开战',
#  '你，有没有过',
#  'Our Singapore',
#  'I Pray For You',
#  '回',
#  '新地球',
#  '水仙',
#  '浪漫血液',
#  '黑键',
#  '手心的蔷薇',
#  '可惜没如果',
#  'I Am Alive',
#  '爱的鼓励',
#  '茉莉雨',
#  '生生',
#  'Checkmate (Bonus Track)',
#  'Lamando',
#  'Checkmate',
#  '回',
#  '新地球',
#  '水仙',
#  '浪漫血液',
#  '黑键',
#  '手心的蔷薇',
#  '可惜没如果',
#  'I Am Alive',
#  '爱的鼓励',
#  '茉莉雨',
#  '生生',
#  'Lamando (上海大众汽车 凌渡特别诚献)',
#  '因你而在',
#  '零度的亲吻',
#  '黑暗骑士',
#  '修炼爱情',
#  '飞机',
#  '巴洛克先生',
#  'One Shot',
#  '裂缝中的阳光',
#  '友人说',
#  '十秒的冲动',
#  '以后要做的事',
#  '一千年后，记得我',
#  '修炼爱情',
#  '他... 是JJ林俊杰... Love~(江南、害怕、小酒窝(solo)、背对背拥抱、她说)',
#  '翅膀',
#  '不懂',
#  '江南',
#  '害怕',
#  '一千年以后',
#  '简简单单',
#  '原来',
#  '西界',
#  '不流泪的机场',
#  '小酒窝',
#  '爱与希望',
#  '第几个100天',
#  '背对背拥抱',
#  '她说',
#  '爱笑的眼睛',
#  '他... 是JJ林俊杰... Dance~(就是我、编号89757、曹操、期待爱、不潮不用花钱)',
#  '就是我',
#  '会读书',
#  '第二天堂',
#  '子弹列车',
#  '编号89757',
#  '木乃伊',
#  '曹操',
#  '波间带',
#  '杀手',
#  '不潮不用花钱',
#  '街道',
#  '期待爱',
#  'X',
#  '加油！',
#  '跟屁虫',
#  '独奏',
#  '学不会',
#  '故事细腻',
#  '那些你很冒险的梦',
#  '白羊梦',
#  '灵魂的共鸣',
#  'We Together',
#  'Cinderella',
#  '白兰花',
#  '陌生老朋友',
#  '不存在的情人',
#  'Love U U',
#  '曹操 (Live)',
#  '杀手 (Live)',
#  '编号89757 (Live)',
#  '冻结 (Live)',
#  '사랑해요只对你说 (Live)',
#  '背对背拥抱 (Live)',
#  'X (Live)',
#  '黑武士 (Live)',
#  '第二天堂 (Live)',
#  '她说 (Live)',
#  '他说:她说 金曲组曲 (Live)',
#  '妈妈的娜鲁娃 (Live)',
#  '加油 (Live)',
#  '无法克制 (Live)',
#  '一个又一个 (Live)',
#  'I AM (Live)',
#  '记得 (Live)',
#  '期待爱 (Live)',
#  '豆浆油条 (Live)',
#  '主角 (Live)',
#  '跟屁虫 (Live)',
#  '街道 (Live)',
#  '波间带 (Live)',
#  '江南 (Live)',
#  '小酒窝 (Live)',
#  '爱笑的眼睛 (Live)',
#  '不潮不用花钱 (Live)',
#  '转动 (Live)',
#  '一千年以后 (Live)',
#  '她说',
#  '爱笑的眼睛',
#  '只对你有感觉',
#  '当你',
#  '一眼万年',
#  '保护色',
#  '握不住的他',
#  '心墙',
#  '我很想爱他',
#  '一生的爱',
#  '记得',
#  '完美新世界',
#  'I AM',
#  '真材实料的我',
#  '第几个100天 (Live)',
#  '翅膀 (Live)',
#  '背对背拥抱 (Live)',
#  '无法克制 (Live)',
#  '一个又一个 (Live)',
#  '豆浆油条 (Live)',
#  '妈妈的娜鲁娃 (Live)',
#  '爱与希望 (Live)',
#  '记得+心墙+当你 (Live)',
#  '小酒窝 (Live)',
#  '转动 (Live)',
#  '加油 (Live)',
#  'Cheer Singapore',
#  '感动每一刻',
#  '妈妈的娜鲁娃(Demo)',
#  '梦想的翅膀',
#  'X',
#  '第几个100天',
#  '加油！',
#  '曙光',
#  '无法克制',
#  '背对背拥抱',
#  '跟屁虫',
#  '一个又一个',
#  '爱不会绝迹',
#  '转动',
#  '妈妈的娜鲁娃',
#  'Still Moving Under Gunfire',
#  '表达爱',
#  '微笑上海',
#  'SIXOLOGY',
#  '不潮不用花钱',
#  '小酒窝',
#  '黑武士',
#  '醉赤壁',
#  '由你选择',
#  'Always Online',
#  '街道',
#  '主角',
#  '我还想她',
#  '点一把火炬',
#  '期待爱',
#  'Cries in a Distance',
#  '爱与希望',
#  '听见幸福',
#  'Hurray一起摇',
#  '独白',
#  '杀手',
#  '西界',
#  '杀手@续',
#  '无聊',
#  'K-O',
#  '大男人·小女孩',
#  '单挑',
#  'L-O-V-E',
#  '发现爱',
#  '不流泪的机场',
#  'Baby Baby',
#  '自由不变',
#  '江南(粤语版)',
#  '忘记',
#  '木乃伊 (Live)',
#  '编号89757 (Live)',
#  '翅膀 (Live)',
#  '原来 (Live)',
#  '简简单单 (Live)',
#  '明天 (Live)',
#  '盗 (Live)',
#  '就是我 (Live)',
#  '不可思议 (Live)',
#  '被风吹过的夏天 (Live)',
#  '爱笑的眼睛 (Live)',
#  'I Do (Live)',
#  '记得 (Live)',
#  '听不懂没关系 (Live)',
#  '熟能生巧 (Live)',
#  '黑色幽默 (Live)',
#  '唯一 (Live)',
#  '第二天堂 (Live)',
#  '子弹列车 (Live)',
#  '进化论 (Live)',
#  '美人鱼 (Live)',
#  '豆浆油条 (Live)',
#  '波间带 (Live)',
#  '一千年以后 (Live)',
#  '사랑해요只对你说 (Live)',
#  '江南 (Live)',
#  '忘记',
#  '忘记',
#  '木乃伊 (Live)',
#  '开场白 (Live)',
#  '翅膀 (Live)',
#  '善与恶 (Live)',
#  '明天 (Live)',
#  '就是我 (Live)',
#  '被风吹过的夏天 (Live)',
#  '爱笑的眼睛 (Live)',
#  'I Do (Live)',
#  '记得 (Live)',
#  '听不懂 没关系 (Live)',
#  '熟能生巧 (Live)',
#  '决战时刻 (Live)',
#  '第二天堂 (Live)',
#  '子弹列车 (Live)',
#  '进化论 (Live)',
#  '一千年以后 (Live)',
#  'Encore (Live)',
#  '莎郎嘿哟只对你说 (Live)',
#  '英雄再现 (Live)',
#  '江南 (Live)',
#  '幕后英雄 (Live)',
#  '사랑해요只对你说',
#  '曹操',
#  '熟能生巧',
#  '波间带',
#  '原来',
#  '不死之身',
#  '爱情Yogurt',
#  '进化论',
#  "Now That She's Gone",
#  '你要的不是我',
#  'Down (Demo)',
#  '流行主教',
#  '流行主教',
#  '一千年以前',
#  '木乃伊',
#  '编号89757',
#  '莎士比亚的天份',
#  '突然累了',
#  '明天',
#  '简简单单',
#  '无尽的思念',
#  '盗',
#  '听不懂 没关系',
#  '来不及了',
#  '一千年以后',
#  '一开始',
#  '第二天堂',
#  '子弹列车',
#  '起床了',
#  '豆浆油条',
#  '江南',
#  '害怕',
#  '天使心',
#  '森林浴',
#  '精灵',
#  '相信无限',
#  '美人鱼',
#  '距离',
#  '未完成',
#  'Endless Road',
#  '就是我',
#  '会读书',
#  '翅膀',
#  '星球',
#  '冻结',
#  '压力',
#  '女儿家',
#  '星空下的吻',
#  '让我心动的人',
#  '会有那么一天',
#  '不懂']

# %%
# 对歌曲名进行过滤
cleaned_songs = []
for song in all_songs:
    if '(' in song:
        continue
    cleaned_songs.append(song)

# %%
cleaned_songs
# Out:
# ['The Show',
#  '愿与愁',
#  '逆光白',
#  '孤独娱乐',
#  '梦不凌乱',
#  '自画像',
#  '谢幕',
#  '如果我还剩一件事情可以做',
#  '黑色泡沫',
#  '你都在',
#  '一时的选择',
#  'Castle in the air',
#  '7千3百多天',
#  '愿与愁',
#  'In The Joy',
#  '谢幕',
#  'Intro',
#  'Too Bad',
#  '身后',
#  '想见你想见你想见你',
#  '恨幸福来过',
#  '慢慢喜欢你',
#  'You Are The Reason',
#  '咖啡+交换余生',
#  '圣所',
#  '生生',
#  '我还年轻 我还年轻',
#  '你啊你啊',
#  '那女孩对我说',
#  '落在生命里的光',
#  '是你',
#  '达尔文',
#  '7千3百多天',
#  '无拘',
#  'From The Ashes',
#  'At Least I Had You',
#  "You're My Superhero",
#  'Positive Procrastination',
#  'Help!',
#  'Better With You',
#  '你還不知道?',
#  'A Day At A Time',
#  '一定会',
#  'After The Rain',
#  'At Least I Had You',
#  '裹着心的光',
#  'While I Can',
#  'Like You Do',
#  'Not Tonight',
#  'All In Your Mind',
#  'Head On',
#  'Steady My Love',
#  '过',
#  '最向往的地方',
#  '交换余生',
#  '幸存者',
#  '离开的那一些',
#  '最好是',
#  '暂时的记号',
#  '交换余生',
#  '背对背拥抱',
#  'As I Believe',
#  'Wonderland',
#  '将故事写成我们',
#  '对的时间点',
#  'As I Believe',
#  '我们很好',
#  '进阶',
#  '飞云之下',
#  'Despacito 缓缓',
#  '圣所',
#  '伟大的渺小',
#  '穿越',
#  '四点四十四',
#  '我继续',
#  '剪云者',
#  '黑夜问白天',
#  '丹宁执着',
#  '身为风帆',
#  '小瓶子',
#  'Until the Day',
#  '黑夜问白天',
#  '小瓶子',
#  '伟大的渺小',
#  'Until The Day',
#  '丹宁执着',
#  '2infinity And Beyond',
#  '超越无限',
#  '序曲：调音',
#  '不为谁而作的歌',
#  '序曲：中场休息',
#  '关键词',
#  '弹唱',
#  '有梦不难',
#  '序曲：Welcome to the Livehouse',
#  'Too Bad',
#  '序曲：12年前',
#  '现在的我和她',
#  '序曲：海边 初',
#  'Lier and Accuser',
#  '独舞',
#  '序曲：海边 终',
#  '你，有没有过',
#  '只要有你的地方',
#  '有梦不难',
#  '不为谁而作的歌',
#  'Dreams',
#  '只要有你的地方',
#  '全面开战',
#  '你，有没有过',
#  'Our Singapore',
#  'I Pray For You',
#  '回',
#  '新地球',
#  '水仙',
#  '浪漫血液',
#  '黑键',
#  '手心的蔷薇',
#  '可惜没如果',
#  'I Am Alive',
#  '爱的鼓励',
#  '茉莉雨',
#  '生生',
#  'Lamando',
#  'Checkmate',
#  '回',
#  '新地球',
#  '水仙',
#  '浪漫血液',
#  '黑键',
#  '手心的蔷薇',
#  '可惜没如果',
#  'I Am Alive',
#  '爱的鼓励',
#  '茉莉雨',
#  '生生',
#  '因你而在',
#  '零度的亲吻',
#  '黑暗骑士',
#  '修炼爱情',
#  '飞机',
#  '巴洛克先生',
#  'One Shot',
#  '裂缝中的阳光',
#  '友人说',
#  '十秒的冲动',
#  '以后要做的事',
#  '一千年后，记得我',
#  '修炼爱情',
#  '翅膀',
#  '不懂',
#  '江南',
#  '害怕',
#  '一千年以后',
#  '简简单单',
#  '原来',
#  '西界',
#  '不流泪的机场',
#  '小酒窝',
#  '爱与希望',
#  '第几个100天',
#  '背对背拥抱',
#  '她说',
#  '爱笑的眼睛',
#  '就是我',
#  '会读书',
#  '第二天堂',
#  '子弹列车',
#  '编号89757',
#  '木乃伊',
#  '曹操',
#  '波间带',
#  '杀手',
#  '不潮不用花钱',
#  '街道',
#  '期待爱',
#  'X',
#  '加油！',
#  '跟屁虫',
#  '独奏',
#  '学不会',
#  '故事细腻',
#  '那些你很冒险的梦',
#  '白羊梦',
#  '灵魂的共鸣',
#  'We Together',
#  'Cinderella',
#  '白兰花',
#  '陌生老朋友',
#  '不存在的情人',
#  'Love U U',
#  '她说',
#  '爱笑的眼睛',
#  '只对你有感觉',
#  '当你',
#  '一眼万年',
#  '保护色',
#  '握不住的他',
#  '心墙',
#  '我很想爱他',
#  '一生的爱',
#  '记得',
#  '完美新世界',
#  'I AM',
#  '真材实料的我',
#  'Cheer Singapore',
#  '感动每一刻',
#  '梦想的翅膀',
#  'X',
#  '第几个100天',
#  '加油！',
#  '曙光',
#  '无法克制',
#  '背对背拥抱',
#  '跟屁虫',
#  '一个又一个',
#  '爱不会绝迹',
#  '转动',
#  '妈妈的娜鲁娃',
#  'Still Moving Under Gunfire',
#  '表达爱',
#  '微笑上海',
#  'SIXOLOGY',
#  '不潮不用花钱',
#  '小酒窝',
#  '黑武士',
#  '醉赤壁',
#  '由你选择',
#  'Always Online',
#  '街道',
#  '主角',
#  '我还想她',
#  '点一把火炬',
#  '期待爱',
#  'Cries in a Distance',
#  '爱与希望',
#  '听见幸福',
#  'Hurray一起摇',
#  '独白',
#  '杀手',
#  '西界',
#  '杀手@续',
#  '无聊',
#  'K-O',
#  '大男人·小女孩',
#  '单挑',
#  'L-O-V-E',
#  '发现爱',
#  '不流泪的机场',
#  'Baby Baby',
#  '自由不变',
#  '忘记',
#  '忘记',
#  '忘记',
#  '사랑해요只对你说',
#  '曹操',
#  '熟能生巧',
#  '波间带',
#  '原来',
#  '不死之身',
#  '爱情Yogurt',
#  '进化论',
#  "Now That She's Gone",
#  '你要的不是我',
#  '流行主教',
#  '流行主教',
#  '一千年以前',
#  '木乃伊',
#  '编号89757',
#  '莎士比亚的天份',
#  '突然累了',
#  '明天',
#  '简简单单',
#  '无尽的思念',
#  '盗',
#  '听不懂 没关系',
#  '来不及了',
#  '一千年以后',
#  '一开始',
#  '第二天堂',
#  '子弹列车',
#  '起床了',
#  '豆浆油条',
#  '江南',
#  '害怕',
#  '天使心',
#  '森林浴',
#  '精灵',
#  '相信无限',
#  '美人鱼',
#  '距离',
#  '未完成',
#  'Endless Road',
#  '就是我',
#  '会读书',
#  '翅膀',
#  '星球',
#  '冻结',
#  '压力',
#  '女儿家',
#  '星空下的吻',
#  '让我心动的人',
#  '会有那么一天',
#  '不懂']

# %%
# 保存到文件中
import pandas as pd
songs = pd.DataFrame(columns=["songs"], data=cleaned_songs)
songs.to_csv("all_songs.csv")
